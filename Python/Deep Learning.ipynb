# %%
import graphlab

# %%
image_train = graphlab.SFrame('image_train_data/')
image_test = graphlab.SFrame('image_test_data/')

# %%
image_train['label'].sketch_summary()
# Out:
# +------------------+-------+----------+
# |       item       | value | is exact |
# +------------------+-------+----------+
# |      Length      |  2005 |   Yes    |
# | # Missing Values |   0   |   Yes    |
# | # unique values  |   4   |    No    |
# +------------------+-------+----------+
#
# Most frequent items:
# +-------+------------+-----+-----+------+
# | value | automobile | cat | dog | bird |
# +-------+------------+-----+-----+------+
# | count |    509     | 509 | 509 | 478  |
# +-------+------------+-----+-----+------+

# %%
graphlab.canvas.set_target('ipynb')
cat = image_train[0:1]
cat['image'].show()

# %%
knn_model = graphlab.nearest_neighbors.create(image_test,features=['deep_features'],
                                             label='id')
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.

# %%
cat = image_test[0:1]['image']
cat
# Out:
# dtype: Image
# Rows: 1
# ['Height: 32 Width: 32']

# %%
def get_images_from_ids(query_result):
    return image_train.filter_by(query_result['reference_label'],'id')

# %%
#cat_neighbors = get_images_from_ids(knn_model.query(cat))
knn_model.query(cat)
# Out:
# ---------------------------------------------------------------------------
# ToolkitError                              Traceback (most recent call last)
# <ipython-input-24-dc438a04d708> in <module>()
#       1 #cat_neighbors = get_images_from_ids(knn_model.query(cat))
# ----> 2 knn_model.query(cat)
#
# /Users/krishna/.graphlab/anaconda/lib/python2.7/site-packages/graphlab/toolkits/nearest_neighbors/_nearest_neighbors.pyc in query(self, dataset, label, k, radius, verbose)
#     951
#     952         ## Validate the 'dataset' input
# --> 953         _tkutl._raise_error_if_not_sframe(dataset, "dataset")
#     954         _tkutl._raise_error_if_sframe_empty(dataset, "dataset")
#     955
#
# /Users/krishna/.graphlab/anaconda/lib/python2.7/site-packages/graphlab/toolkits/_internal_utils.pyc in _raise_error_if_not_sframe(dataset, variable_name)
#     344
#     345     if not isinstance(dataset, _SFrame):
# --> 346       raise ToolkitError, err_msg % variable_name
#     347
# ...

# %%
cat_images = image_train[image_train['label']=='cat']

# %%
cat_model = graphlab.nearest_neighbors.create(cat_images,
features=['deep_features'], label='id')
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.

# %%
cat_model.query(image_test[0:1])
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.196464    | 19.958ms     |
# PROGRESS: | Done         |         | 100         | 104.816ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |      16289      |  34.623719208 |  1   |
# |      0      |      45646      | 36.0068799284 |  2   |
# |      0      |      32139      | 36.5200813436 |  3   |
# |      0      |      25713      | 36.7548502521 |  4   |
# ...

# %%
def get_images_from_ids(query_result):
    return image_train.filter_by(
    query_result['reference_label'], 'id')
#then run
get_images_from_ids(cat_model.query(image_train[0:1])).show()
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.196464    | 24.5ms       |
# PROGRESS: | Done         |         | 100         | 95.308ms     |
# PROGRESS: +--------------+---------+-------------+--------------+

# %%
## Dog Model

# %%
dog_images = image_train[image_train['label']=='dog']

# %%
knn_model_dog = graphlab.nearest_neighbors.create(dog_images,features=['deep_features'],
                                             label='id')
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.

# %%
dog_cat_neighbors = knn_model_dog.query(dog_images, k=1)
# Out:
# PROGRESS: Starting blockwise querying.
# PROGRESS: max rows per data block: 7668
# PROGRESS: number of reference data blocks: 4
# PROGRESS: number of query data blocks: 1
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 509          | 65152   | 25.1473     | 280.413ms    |
# PROGRESS: | Done         | 259081  | 100         | 326.364ms    |
# PROGRESS: +--------------+---------+-------------+--------------+

# %%
dog_cat_neighbors
# Out:
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 509
#
# Data:
# +-------------+-----------------+-------------------+------+
# | query_label | reference_label |      distance     | rank |
# +-------------+-----------------+-------------------+------+
# |      0      |        70       |        0.0        |  1   |
# |      1      |       107       |        0.0        |  1   |
# |      2      |       177       |        0.0        |  1   |
# |      3      |       424       | 2.52318507296e-06 |  1   |
# |      4      |       462       | 2.33601545599e-06 |  1   |
# |      5      |       542       |        0.0        |  1   |
# |      6      |       573       |        0.0        |  1   |
# |      7      |       851       |        0.0        |  1   |
# |      8      |       919       |        0.0        |  1   |
# |      9      |       1172      |        0.0        |  1   |
# +-------------+-----------------+-------------------+------+
# ...

# %% [markdown]
# Question 2
# =====

# %%
image_train_dog = image_train[image_train['label']=='dog'] 
image_train_cat = image_train[image_train['label']=='cat']
image_train_car = image_train[image_train['label']=='car'] 
image_train_bird = image_train[image_train['label']=='bird']

# %%
knn_model_cat = graphlab.nearest_neighbors.create(image_train_cat,features=['deep_features'],
                                             label='id')
def get_images_from_ids(query_result):
    return image_train.filter_by(
    query_result['reference_label'], 'id')
#then run
get_images_from_ids(knn_model_cat.query(image_test[0:1])).show()
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.196464    | 18.998ms     |
# PROGRESS: | Done         |         | 100         | 83.373ms     |
# PROGRESS: +--------------+---------+-------------+--------------+

# %%
knn_model_dog = graphlab.nearest_neighbors.create(image_train_dog,features=['deep_features'],
                                             label='id')
def get_images_from_ids(query_result):
    return image_train.filter_by(
    query_result['reference_label'], 'id')
#then run
get_images_from_ids(knn_model_dog.query(image_test[0:1]))
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.196464    | 18.897ms     |
# PROGRESS: | Done         |         | 100         | 103.128ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	id	int
# 	image	Image
# 	label	str
# 	deep_features	array
# 	image_array	array
#
# Rows: 5
#
# Data:
# +-------+----------------------+-------+-------------------------------+
# |   id  |        image         | label |         deep_features         |
# +-------+----------------------+-------+-------------------------------+
# |  6094 | Height: 32 Width: 32 |  dog  | [0.470533549786, 0.0, 0.0,... |
# ...

# %%
knn_model_dog.query(image_test[0:1])
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.196464    | 24.47ms      |
# PROGRESS: | Done         |         | 100         | 111.678ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |      16976      | 37.4642628784 |  1   |
# |      0      |      13387      | 37.5666832169 |  2   |
# |      0      |      35867      | 37.6047267079 |  3   |
# |      0      |      44603      | 37.7065585153 |  4   |
# ...

# %%
# Out:
# Columns:
# 	id	int
# 	image	Image
# 	label	str
# 	deep_features	array
# 	image_array	array
#
# Rows: 1
#
# Data:
# +----+----------------------+-------+-------------------------------+
# | id |        image         | label |         deep_features         |
# +----+----------------------+-------+-------------------------------+
# | 0  | Height: 32 Width: 32 |  cat  | [1.13469004631, 0.0, 0.0, ... |
# +----+----------------------+-------+-------------------------------+
# +-------------------------------+
# |          image_array          |
# +-------------------------------+
# | [158.0, 112.0, 49.0, 159.0... |
# +-------------------------------+
# [1 rows x 5 columns]

# %%
knn_model_cat.query(image_test[0:1])
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.196464    | 19.972ms     |
# PROGRESS: | Done         |         | 100         | 116.976ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |      16289      |  34.623719208 |  1   |
# |      0      |      45646      | 36.0068799284 |  2   |
# |      0      |      32139      | 36.5200813436 |  3   |
# |      0      |      25713      | 36.7548502521 |  4   |
# ...
